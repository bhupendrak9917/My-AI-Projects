# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
import glob
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
epochs = 100
l_r = 1e-3
batch_size = 64
img_dims = (96,96,3)

# %%
data = []
labels = []

# %%
image_files = [f for f in glob.glob(r'C:\Users\bhupe\Desktop\My Project\Gender Classification\gender_dataset_face' + "/**/*", recursive=True) if not os.path.isdir(f)]
random.shuffle(image_files)

# %%
for img in image_files:

    image = cv2.imread(img)
    
    image = cv2.resize(image, (img_dims[0],img_dims[1]))
    image = img_to_array(image)
    data.append(image)

    label = img.split(os.path.sep)[-2]
    if label == "woman":
        label = 1
    else:
        label = 0
        
    labels.append([label])

# %%
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2,
                                                  random_state=42)

trainY = to_categorical(trainY, num_classes=2)
testY = to_categorical(testY, num_classes=2)

# %%
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# %%
def build(width, height, depth, classes):
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1

    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1
    

    model.add(Conv2D(32, (3,3), padding="same", input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3,3)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(classes))
    model.add(Activation("sigmoid"))

    return model

# %%
model = build(width=img_dims[0], height=img_dims[1], depth=img_dims[2],
                            classes=2)

# %%
opt = Adam(learning_rate=l_r, decay=l_r/epochs)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# %%
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=batch_size),
                        validation_data=(testX,testY),
                        steps_per_epoch=len(trainX) // batch_size,
                        epochs=epochs, verbose=1)
# Out:
# c:\users\bhupe\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\keras\engine\training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 50/50 [==============================] - 120s 2s/step - loss: 0.9080 - accuracy: 0.6649 - val_loss: 1.5459 - val_accuracy: 0.5113
# Epoch 2/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.4578 - accuracy: 0.8225 - val_loss: 0.8274 - val_accuracy: 0.5387
# Epoch 3/100
# 50/50 [==============================] - 114s 2s/step - loss: 0.3779 - accuracy: 0.8440 - val_loss: 1.2657 - val_accuracy: 0.5675
# Epoch 4/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.3588 - accuracy: 0.8619 - val_loss: 0.9230 - val_accuracy: 0.5900
# Epoch 5/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.3071 - accuracy: 0.8822 - val_loss: 0.8937 - val_accuracy: 0.5575
# Epoch 6/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.2348 - accuracy: 0.9119 - val_loss: 0.8179 - val_accuracy: 0.6438
# Epoch 7/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.2429 - accuracy: 0.9048 - val_loss: 1.4923 - val_accuracy: 0.6125
# Epoch 8/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.2244 - accuracy: 0.9118 - val_loss: 0.4664 - val_accuracy: 0.7975
# Epoch 9/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.1844 - accuracy: 0.9306 - val_loss: 0.4086 - val_accuracy: 0.8737
# Epoch 10/100
# 50/50 [==============================] - 114s 2s/step - loss: 0.1855 - accuracy: 0.9277 - val_loss: 0.2340 - val_accuracy: 0.9112
# Epoch 11/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.1634 - accuracy: 0.9390 - val_loss: 0.3961 - val_accuracy: 0.8838
# Epoch 12/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.1908 - accuracy: 0.9294 - val_loss: 0.2177 - val_accuracy: 0.9250
# Epoch 13/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.1632 - accuracy: 0.9356 - val_loss: 0.7895 - val_accuracy: 0.8025
# Epoch 14/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.1540 - accuracy: 0.9328 - val_loss: 0.6390 - val_accuracy: 0.8313
# Epoch 15/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.1432 - accuracy: 0.9449 - val_loss: 0.1955 - val_accuracy: 0.9400
# Epoch 16/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.1257 - accuracy: 0.9509 - val_loss: 0.3547 - val_accuracy: 0.8850
# Epoch 17/100
# 50/50 [==============================] - 111s 2s/step - loss: 0
100
# 50/50 [==============================] - 112s 2s/step - loss: 0.0663 - accuracy: 0.9732 - val_loss: 0.1859 - val_accuracy: 0.9500
# Epoch 76/100
# 50/50 [==============================] - 113s 2s/step - loss: 0.0667 - accuracy: 0.9733 - val_loss: 0.1992 - val_accuracy: 0.9225
# Epoch 77/100
# 50/50 [==============================] - 113s 2s/step - loss: 0.0528 - accuracy: 0.9781 - val_loss: 0.1543 - val_accuracy: 0.9525
# Epoch 78/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.0737 - accuracy: 0.9684 - val_loss: 0.1452 - val_accuracy: 0.9525
# Epoch 79/100
# 50/50 [==============================] - 115s 2s/step - loss: 0.0619 - accuracy: 0.9759 - val_loss: 0.0986 - val_accuracy: 0.9712
# Epoch 80/100
# 50/50 [==============================] - 114s 2s/step - loss: 0.0518 - accuracy: 0.9835 - val_loss: 0.5966 - val_accuracy: 0.8662
# Epoch 81/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.0598 - accuracy: 0.9740 - val_loss: 0.1148 - val_accuracy: 0.9575
# Epoch 82/100
# 50/50 [==============================] - 114s 2s/step - loss: 0.0501 - accuracy: 0.9786 - val_loss: 0.5483 - val_accuracy: 0.8600
# Epoch 83/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0523 - accuracy: 0.9801 - val_loss: 0.7612 - val_accuracy: 0.8188
# Epoch 84/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0480 - accuracy: 0.9783 - val_loss: 0.1857 - val_accuracy: 0.9500
# Epoch 85/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0552 - accuracy: 0.9814 - val_loss: 0.1744 - val_accuracy: 0.9362
# Epoch 86/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0482 - accuracy: 0.9822 - val_loss: 0.4852 - val_accuracy: 0.8725
# Epoch 87/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0493 - accuracy: 0.9840 - val_loss: 0.2732 - val_accuracy: 0.9250
# Epoch 88/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0475 - accuracy: 0.9844 - val_loss: 0.2028 - val_accuracy: 0.9463
# Epoch 89/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0556 - accuracy: 0.9764 - val_loss: 0.1405 - val_accuracy: 0.9625
# Epoch 90/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0528 - accuracy: 0.9785 - val_loss: 0.4839 - val_accuracy: 0.8450
# Epoch 91/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0483 - accuracy: 0.9831 - val_loss: 0.3960 - val_accuracy: 0.8813
# Epoch 92/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0643 - accuracy: 0.9773 - val_loss: 0.1062 - val_accuracy: 0.9675
# Epoch 93/100
# 50/50 [==============================] - 108s 2s/step - loss: 0.0528 - accuracy: 0.9819 - val_loss: 0.1475 - val_accuracy: 0.9638
# Epoch 94/100
# 50/50 [==============================] - 111s 2s/step - loss: 0.0562 - accuracy: 0.9798 - val_loss: 0.1517 - val_accuracy: 0.9438
# Epoch 95/100
# 50/50 [==============================] - 110s 2s/step - loss: 0.0602 - accuracy: 0.9764 - val_loss: 0.1207 - val_accuracy: 0.9650
# Epoch 96/100
# 50/50 [==============================] - 112s 2s/step - loss: 0.0416 - accuracy: 0.9844 - val_loss: 0.2120 - val_accuracy: 0.9450
# Epoch 97/100
# 50/50 [==============================] - 110s 2s/step - loss: 0.0443 - accuracy: 0.9829 - val_loss: 0.1249 - val_accuracy: 0.9588
# Epoch 98/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0497 - accuracy: 0.9793 - val_loss: 0.1139 - val_accuracy: 0.9725
# Epoch 99/100
# 50/50 [==============================] - 109s 2s/step - loss: 0.0665 - accuracy: 0.9779 - val_loss: 0.3762 - val_accuracy: 0.8863
# Epoch 100/100
# 50/50 [==============================] - 110s 2s/step - loss: 0.0476 - accuracy: 0.9800 - val_loss: 0.1421 - val_accuracy: 0.9600

# %%
model.save('gender_detection.model')
# Out:
# INFO:tensorflow:Assets written to: gender_detection.model\assets

# %%
plt.style.use("ggplot")
plt.figure()
N = epochs
plt.plot(np.arange(0,N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0,N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0,N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0,N), H.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")

plt.savefig('plot.png')
